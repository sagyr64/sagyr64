# %% [markdown]
# <a href="https://colab.research.google.com/github/sagyr64/sagyr64/blob/main/Maximum_Common_Substructure_Part_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Search for a Maximum common substructure
#
# My name is **Dr. Ashfaq Ahmad**, and this tutorial is inspired from the TeachOpenCADD project of Volkamer Lab. Students and Researchers with a basic Biology background found difficult to run these analysis directly. Therefore, with some minor modification, this notebook allows everyone to directly use it for analysis. Also this notebook is primarily cloned for teaching and research purposes. For a detail video tutorial, Bioinformatics Insights https://www.youtube.com/channel/UC2Z_WaqTjbvXGGQNpIF9nAg
#
# Authors:
#
# - Oliver Nagel, CADD Seminars, 2017, Charité/FU Berlin
# - Jaime Rodríguez-Guerra, 2019-2020, [Volkamer lab](https://volkamerlab.org), Charité
# - Andrea Volkamer, 2019-2020, [Volkamer lab](https://volkamerlab.org), Charité

# %% [markdown]
# ## Aim of this talktorial
#
# Clustering and classification of large scale chemical data is essential for navigation, analysis and knowledge discovery in a wide variety of chemical application domains in drug discovery.
#
# In the last talktorial, we learned how to group molecules (clustering) and found that the molecules in one cluster look similar to each other and share a common scaffold. Besides visual inspection, we will learn here how to calculate the maximum substructure that a set of molecules has in common.

# %% [markdown]
# ### Contents in *Theory*
#
# * Introduction to identification of maximum common substructure in a set of molecules
# * Detailed explanation of the FMCS algorithm

# %% [markdown]
# ### Contents in *Practical*
#
# * Load and draw molecules
# * Run the FMCS algorithm with different input parameters
# * A more diverse set: the EGFR compounds downloaded from ChEMBL
# * Identification of MCS using interactive cut-off adaption

# %% [markdown]
# ### References
#
# * Dalke A, Hastings J., FMCS: a novel algorithm for the multiple MCS problem. [*J. Cheminf.* 2013; **5** (Suppl 1): O6](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3606201/)
# * Raymond JW., Willet P., Maximum common subgraph isomorphism algorithms for the matching of chemical structures. [*J Comput Aided Mol Des.* 2002 Jul; **16**(7):521-33](https://link.springer.com/article/10.1023/A:1021271615909)
# * [Dalke's website with info on algorithm](http://dalkescientific.com/writings/diary/archive/2012/05/12/mcs_background.html)
# * [RDKit Cookbook documentation on MCS](http://www.rdkit.org/docs/Cookbook.html#using-custom-mcs-atom-types)

# %% [markdown]
# ## Theory

# %% [markdown]
# ### Introduction to identification of maximum common substructure in a set of molecules
#
# ![Maximum common substructure, highlighted](https://github.com/volkamerlab/teachopencadd/blob/master/teachopencadd/talktorials/T006_compound_maximum_common_substructures/images/mymols.png?raw=1)
#
# The maximum common structure (MCS) is defined as the largest substructure that appears in two or more candidate molecules.
#
# * Finding the MCS = maximum common subgraph isomorphism problem
# * Has many applications in the field of cheminformatics: similarity search, hierarchical clustering, or molecule alignment
# * Advantages:
#   * Intuitive $\rightarrow$ shared structure among candidates likely to be important
#   * Provides insight into possible activity patterns
#   * Easy visualization by simply highlighting the substructure
#
# Details on MCS algorithms (see review: [*J Comput Aided Mol Des.* 2002 Jul; **16**(7):521-33](https://link.springer.com/article/10.1023/A:1021271615909))
#
# * Determining an MCS between two or more graphs is an NP-complete problem
# * Algorithms for exact determination as well as approximations exist
#   * Exact: Maximum-clique, backtracking, dynamic programming
#   * Approximate: Genetic algorithm, combinatorial optimization, fragment storage, ...
#   * Problem reduction: Simplify the molecular graphs
#
#
# Example of an implementation: [FMCS](http://dalkescientific.com/writings/diary/archive/2012/05/12/mcs_background.html) algorithm
#
# * Models MCS problem as a graph isomorphism problem
# * Based on subgraph enumeration and subgraph isomorphism testing

# %% [markdown]
# ### Detailed explanation of FMCS algorithm
# As explained in [*J. Cheminf.* 2013; **5**(Suppl 1): O6](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3606201/) and the respective [RDKit FMCS documentation](https://www.rdkit.org/docs/source/rdkit.Chem.fmcs.fmcs.html).

# %% [markdown]
# #### The simplified algorithm description
#
# ```
# best_substructure = None
# pick one structure in the set as query, all other as targets
# for each substructure in the query:
#     convert into a SMARTS string based on the desired match properties
#     if SMARTS pattern exists in all of the targets:
#         then it is a common substructure
#         keep track of the maximum of such substructure
# ```
#
# This simple approach alone will usually take a long time, but there are certain tricks used to speed up the run time.

# %% [markdown]
# #### Tricks to speed up the run time
#
# <img src="https://github.com/volkamerlab/teachopencadd/blob/master/teachopencadd/talktorials/T006_compound_maximum_common_substructures/images/speed_tricks.jpg?raw=1" width=800 />
#
# #### A) Bond elimination
#
#
# * Remove bonds that cannot be part of the MCS
# * Atom and bond type information has to be present in every input structure
# * Bond type: string consisting of SMARTS of the first atom, the bond and the second atom
# * Exclude all bond types not present in all input structures, delete respective edges
# * Result: fragmented structures with all atom information, but fewer edges (bonds)
#
# #### B) Use the structure with the smallest largest fragment as the query
#
# * Heuristic approach:
#     * Find largest fragment of each input structure
#     * Sort input structures ascending by number of bonds in largest fragment
#     * Solve ties with number of atoms or input order as alternative
# * The structure with the smallest largest fragment becomes the query structure
# * The ones from the other input structures are the targets
#
# #### C) Use a breadth-first search (BFS) and a priority queue to enumerate the fragment subgraphs
#
# __C1__
# * Enumeration based on growing a so called seed
# * Seed: atoms/bonds in current subgraph, exclusion set (bonds not applicable for growth)
# * To prevent redundancy:
#     * Initial seed is first bond in the fragment, can potentially grow to size of whole fragment
#     * Second seed is second bond, is excluded from using the first bond
#     * Third seed starts from the third bond, excluded from using the first and second
#     * ...
#
# __C2__
# * Seed grows along connected bonds (not in exclusions set or already in seed)
# * All growing possibilities are considered at every step
# * E.g. if there are N possible bonds for extension, $2^{N-1}$ possible new seeds are added to queue
# * Enumeration ends when there are no new bonds to add to subgraph (exclude seed from queue)
# * Largest seed will be processed first
#
# #### D) Prune seeds not present in all of the other structures
#
# * At each growth state $\rightarrow$ check if new seed exists in all other structures
# * Else: Exclude seed from queue
#
# #### E) Prune seeds without sufficient growing potential
#
# * Evaluation of growth potential from exclusion list and possible edges for extension
# * If potential smaller than current best subgraph  $\rightarrow$  exclude seed from queue
#
# Utilizing these approaches it is then trivial to keep track of the largest subgraph which corresponds to the maximum common substructure.

# %%
#Install Conda - Kernal Restart will take place
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:13
# 🔁 Restarting kernel...

# %%
# Install mamba
# !conda install -c conda-forge mamba -y

# Use mamba to install packages
# !mamba install -c conda-forge -c defaults python=3.8 -y
# !mamba install -c conda-forge -c defaults pip -y
# !mamba install -c conda-forge -c defaults jupyterlab=3 -y
# !mamba install -c conda-forge -c defaults jsonschema=4.3.0 -y
# !mamba install -c conda-forge -c defaults nglview=3 -y
# !mamba install -c conda-forge -c defaults ipywidgets=7.75 -y
# !mamba install -c conda-forge -c defaults jupyter_client=7.4.9 -y
# !mamba install -c conda-forge -c defaults 'numpy<1.24' -y
# !mamba install -c conda-forge -c defaults scikit-learn -y
# !mamba install -c conda-forge -c defaults 'tensorflow<=2.6' -y
# !mamba install -c conda-forge -c defaults seaborn -y
# !mamba install -c conda-forge -c defaults matplotlib-venn -y
# !mamba install -c conda-forge -c defaults bravado -y
# !mamba install -c conda-forge -c defaults requests -y
# !mamba install -c conda-forge -c defaults requests-cache -y
# !mamba install -c conda-forge -c defaults redo -y
# !mamba install -c conda-forge -c defaults suds-community -y
# !mamba install -c conda-forge -c defaults beautifulsoup4 -y
# !mamba install -c conda-forge -c defaults chembl_webresource_client -y
# !mamba install -c conda-forge -c defaults pypdb -y
# !mamba install -c conda-forge -c defaults 'biopython<=1.77' -y
# !mamba install -c conda-forge -c defaults biopandas -y
# !mamba install -c conda-forge -c defaults rdkit -y
# !mamba install -c conda-forge -c defaults openbabel -y
# !mamba install -c conda-forge -c defaults opencadd -y
# !mamba install -c conda-forge -c defaults 'biotite>=0.34.0' -y
# !mamba install -c conda-forge -c defaults smina -y
# !mamba install -c conda-forge -c defaults 'mdanalysis>=1.0.0' -y
# !mamba install -c conda-forge -c defaults mdtraj -y
# !mamba install -c conda-forge -c defaults plip -y
# !mamba install -c conda-forge -c defaults openmm -y
# !mamba install -c conda-forge -c defaults 'mkl<2022' -y
# !mamba install -c pytorch pytorch==1.13.0 -y
# !mamba install -c conda-forge -c defaults pdbfixer -y
# !mamba install -c conda-forge -c defaults tqdm -y
# !mamba install -c conda-forge -c defaults lxml -y
# !mamba install -c conda-forge -c defaults kissim -y
# !mamba install -c conda-forge -c defaults pytest -y
# !mamba install -c conda-forge -c defaults pytest-xdist -y
# !mamba install -c conda-forge -c defaults pytest-cov -y
# !mamba install -c conda-forge -c defaults nbval -y
# !mamba install -c conda-forge -c defaults shyaml -y
# !mamba install -c conda-forge -c defaults 'jinja2==3.0.3' -y
# !mamba install -c conda-forge -c defaults sphinx -y
# !mamba install -c conda-forge -c defaults sphinx-material -y
# !mamba install -c conda-forge -c defaults nbsphinx -y
# !mamba install -c conda-forge -c defaults recommonmark -y
# !mamba install -c conda-forge -c defaults sphinx-autodoc-typehints -y
# !mamba install -c conda-forge -c defaults sphinx-copybutton -y
# !mamba install -c conda-forge -c defaults sphinx-gallery -y
# !mamba install -c conda-forge -c defaults autodocsumm -y

# Install pip packages
# !pip install black-nb nbsphinx-link sphinxext-opengraph deepchem
# Out:
# Streaming output truncated to the last 5000 lines.
#        └─ python =3.11 *, which conflicts with any installable versions previously reported.
# critical libmamba Could not solve for environment specs
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# [+] 0.0s
# [+] 0.0s
# [+] 0.1s
# pkgs/main/noarch  |
# pkgs/r/noarch     ⣾
# Pinned packages:
#
#   - python=3.11
#
# Pinned packages:
#
#   - python_abi[version="=3.11",build="*cp311*"]
#
# Pinned packages:
#
#   - cuda-version=12
#
# Pinned packages:
#
#   - python=3.11
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - biotite>=0.34.0
#
#
#   Package     Version  Build            Channel           Size
# ────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────
#
#   + biotite     1.1.0  py311hfdbb021_1  conda-forge       47MB
#   + biotraj     1.2.2  py311hfdbb021_0  conda-forge        4MB
#   + networkx    3.4.2  pyh267e887_2     conda-forge        1MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────
#
#   - numpy      1.23.5  py311h7d28db0_0  conda-forge     Cached
#   + numpy       2.2.3  py311h5d046bc_0  conda-forge     Cached
#
#   Summary:
#
#   Install: 3 packages
#   Upgrade: 1 packages
#
#   Total download: 52MB
#
# ────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Downloading        5%
# Extracting         0%[+] 0.1s
# Downloading  (3)   0%
# Extracting         0%networkx                                             1.3MB @   5.3MB/s  0.1s
# [+] 0.2s
# Downloading  (2)   3%
# Extracting   (1)  ⣾  [+] 0.3s
# Downloading  (2)  26%
# Extracting   (1)  ⣾  biotraj                                              3.6MB @  10.1MB/s  0.3s
# [+] 0.4s
# Downloading  (1)  60%
# Extracting   (1)  ⣾  [+] 0.5s
# Downloading  (1)  81%
# Extracting   (1)  ⣾  biotite                                             46.9MB @  77.1MB/s  0.5s
# [+] 0.6s
# Downloading      100%
# Extracting        67%[+] 0.7s
# Downloading      100%
# Extracting        67%[+] 0.8s
# Downloading      100%
# Extracting        67%[+] 0.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 1.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 2.0s
# Downloading      100%
# Extracting   (1)  ⣾  Unlinking numpy-1.23.5-py311h7d28db0_0
# Linking numpy-2.2.3-py311h5d046bc_0
# Linking biotraj-1.2.2-py311hfdbb021_0
# Linking networkx-3.4.2-pyh267e887_2
# Linking biotite-1.1.0-py311hfdbb021_1
#
# Transaction finished
#
# To activate this environment, use:
#
#     mamba activate base
#
# Or to execute a single command in this environment, use:
#
#     mamba run -n base mycommand
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# pkgs/main/linux-64                                          Using cache
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# pkgs/main/noarch                                            Using cache
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# pkgs/r/linux-64                                             Using cache
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# pkgs/r/noarch                                               Using cache
# [+] 0.0s
# [+] 0.0s
#
# Pinned packages:
#
#   - python=3.11
#
# Pinned packages:
#
#   - python_abi[version="=3.11",build="*cp311*"]
#
# Pinned packages:
#
#   - cuda-version=12
#
# Pinned packages:
#
#   - python=3.11
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - smina
#
#
#   Package                     Version  Build            Channel           Size
# ────────────────────────────────────────────────────────────────────────────────
#   Install:
# ────────────────────────────────────────────────────────────────────────────────
#
#   + liblzma-devel               5.6.3  hb9d3cd8_1       conda-forge      377kB
#   + smina                  2020.12.10  hd5edb52_1       conda-forge      578kB
#   + xz                          5.6.3  hbcc6ac9_1       conda-forge       23kB
#   + xz-gpl-tools                5.6.3  hbcc6ac9_1       conda-forge       33kB
#   + xz-tools                    5.6.3  hb9d3cd8_1       conda-forge       90kB
#   + zlib                        1.3.1  hb9d3cd8_2       conda-forge       92kB
#
#   Remove:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - librdkit                2024.09.5  h84b0b3c_0       conda-forge     Cached
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - cairo                      1.18.2  h3394656_1       conda-forge     Cached
#   + cairo                      1.18.0  hbb29018_2       conda-forge      984kB
#   - conda                      25.1.1  py311h38be061_1  conda-forge     Cached
#   + conda                      24.9.2  py311h38be061_0  conda-forge        1MB
#   - conda-libmamba-solver      25.1.1  pyhd8ed1ab_0     conda-forge     Cached
#   + conda-libmamba-solver      24.9.0  pyhd8ed1ab_0     conda-forge     Cached
#   - icu                          75.1  he02047a_0       conda-forge     Cached
#   + icu                          73.2  h59595ed_0       conda-forge       12MB
#   - libarchive                  3.7.7  h4585015_3       conda-forge     Cached
#   + libarchive                  3.7.4  hfca40fe_0       conda-forge      872kB
#   - libboost                   1.86.0  h6c02f8c_3       conda-forge     Cached
#   + libboost                   1.82.0  h6fcfa73_6       conda-forge        3MB
#   - libboost-python            1.86.0  py311h5b7b71f_3  conda-forge     Cached
#   + libboost-python            1.82.0  py311h92ebd52_6  conda-forge      120kB
#   - libmamba                    2.0.5  h49b8a8d_1       conda-forge     Cached
#   + libmamba                   1.5.11  hf72d635_0       conda-forge        2MB
#   - libmambapy                  2.0.5  py311hb3373dd_1  conda-forge     Cached
#   + libmambapy                 1.5.11  py311h18a8eac_0  conda-forge      331kB
#   - libpq                        17.4  h27ae623_0       conda-forge     Cached
#   + libpq                        17.0  h8d1a565_0       conda-forge        3MB
#   - libxml2                    2.13.5  h8d12d68_1       conda-forge     Cached
#   + libxml2                    2.12.7  h4c95cb1_3       conda-forge      706kB
#   - lz4-c                      1.10.0  h5888daf_1       conda-forge     Cached
#   + lz4-c                       1.9.4  hcb278e6_0       conda-forge      143kB
#   - mamba                       2.0.5  h8871ed4_1       conda-forge     Cached
#   + mamba                      1.5.11  py311h3072747_0  conda-forge       67kB
#   - numpy                       2.2.3  py311h5d046bc_0  conda-forge     Cached
#   + numpy                      1.26.4  py311h64a7726_0  conda-forge        8MB
#   - rdkit                   2024.09.5  py311h4bf1da0_0  conda-forge     Cached
#   + rdkit                   2023.09.6  py311h4c2f14b_0  conda-forge       39MB
#
#   Summary:
#
#   Install: 6 packages
#   Remove: 1 packages
#   Downgrade: 15 packages
#
#   Total download: 71MB
#
# ────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Downloading        5%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%libpq                                                2.7MB @  11.0MB/s  0.1s
# [+] 0.2s
# Downloading  (5)   6%
# Extracting   (1)  ⣾  libboost                                             2.6MB @ 995.3kB/s  0.1s
# libmamba                                             1.7MB @  10.1MB/s  0.1s
# numpy                                                8.1MB @  26.4MB/s  0.2s
# [+] 0.3s
# Downloading  (4)  34%
# Extracting   (3)  ⣾  conda                                                1.2MB @  ??.?MB/s  0.1s
# cairo                                              984.2kB @   3.2MB/s  0.1s
# libarchive                                         871.9kB @   3.1MB/s  0.1s
# libxml2                                            705.7kB @  10.4MB/s  0.1s
# smina                                              578.0kB @  ??.?MB/s  0.0s
# [+] 0.4s
# Downloading  (5)  50%
# Extracting   (9)  ⣾  lz4-c                                              143.4kB @  ??.?MB/s  0.0s
# liblzma-devel                                      376.8kB @  ??.?MB/s  0.0s
# libmambapy                                         330.9kB @  ??.?MB/s  0.1s
# icu                                                 12.1MB @  22.8MB/s  0.4s
# libboost-python                                    119.7kB @  ??.?MB/s  0.1s
# zlib                                                92.3kB @  ??.?MB/s  0.1s
# [+] 0.5s
# Downloading  (5)  75%
# Extracting  (13)  ⣾  xz-tools                                            90.4kB @  ??.?MB/s  0.1s
# mamba                                               66.7kB @  ??.?MB/s  0.1s
# xz-gpl-tools                                        33.4kB @  ??.?MB/s  0.1s
# xz                                                  23.5kB @  ??.?MB/s  0.1s
# rdkit                                               38.7MB @  64.7MB/s  0.5s
# [+] 0.6s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 0.7s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 0.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 0.9s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 1.0s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 1.1s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 1.2s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 1.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.4s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 1.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 1.9s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 2.0s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 2.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 2.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting   (1)  ⣾  Unlinking librdkit-2024.09.5-h84b0b3c_0
# Unlinking icu-75.1-he02047a_0
# Unlinking numpy-2.2.3-py311h5d046bc_0
# Unlinking lz4-c-1.10.0-h5888daf_1
# Unlinking libpq-17.4-h27ae623_0
# Unlinking libboost-python-1.86.0-py311h5b7b71f_3
# Unlinking cairo-1.18.2-h3394656_1
# Unlinking libboost-1.86.0-h6c02f8c_3
# Unlinking libxml2-2.13.5-h8d12d68_1
# Unlinking rdkit-2024.09.5-py311h4bf1da0_0
# Unlinking libarchive-3.7.7-h4585015_3
# Unlinking libmamba-2.0.5-h49b8a8d_1
# Unlinking libmambapy-2.0.5-py311hb3373dd_1
# Unlinking conda-25.1.1-py311h38be061_1
# Unlinking conda-libmamba-solver-25.1.1-pyhd8ed1ab_0
# Unlinking mamba-2.0.5-h8871ed4_1
# Linking icu-73.2-h59595ed_0
# Linking numpy-1.26.4-py311h64a7726_0
# Linking zlib-1.3.1-hb9d3cd8_2
# Linking lz4-c-1.9.4-hcb278e6_0
# Linking liblzma-devel-5.6.3-hb9d3cd8_1
# Linking xz-gpl-tools-5.6.3-hbcc6ac9_1
# Linking xz-tools-5.6.3-hb9d3cd8_1
# Linking libpq-17.0-h8d1a565_0
# Linking libboost-python-1.82.0-py311h92ebd52_6
# Linking cairo-1.18.0-hbb29018_2
# Linking xz-5.6.3-hbcc6ac9_1
# Linking libboost-1.82.0-h6fcfa73_6
# Linking libxml2-2.12.7-h4c95cb1_3
# Linking rdkit-2023.09.6-py311h4c2f14b_0
# Linking smina-2020.12.10-hd5edb52_1
# Linking libarchive-3.7.4-hfca40fe_0
# Linking libmamba-1.5.11-hf72d635_0
# Linking libmambapy-1.5.11-py311h18a8eac_0
# Linking conda-24.9.2-py311h38be061_0
# Linking conda-libmamba-solver-24.9.0-pyhd8ed1ab_0
# warning  libmamba [conda-libmamba-solver-24.9.0-pyhd8ed1ab_0] The following files were already present in the environment:
#     - lib/python3.11/site-packages/conda_libmamba_solver/__init__.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/conda_build_exceptions.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/exceptions.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/index.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/mamba_utils.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/plugin.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/repoquery.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/solver.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/state.py
#     - lib/python3.11/site-packages/conda_libmamba_solver/utils.py
# Linking mamba-1.5.11-py311h3072747_0
#
# Transaction finished
#
# To activate this environment, use:
#
#     mamba (deleted) activate base
#
# Or to execute a single command in this environment, use:
#
#     mamba (deleted) run -n base mycommand
#
#
# Looking for: ["mdanalysis[version='>=1.0.0']"]
#
# warning  libmamba Could not parse mod/etag header
# warning  libmamba Could not parse mod/etag header
# [+] 0.0s
# pkgs/main/linux-64..  ⣾  pkgs/main/linux-64 (check zst)
# [+] 0.0s
# pkgs/main/noarch (..  ⣾  pkgs/main/noarch (check zst)
# [+] 0.0s
# pkgs/r/linux-64 (c..  ⣾  pkgs/r/linux-64 (check zst)
# [+] 0.0s
# pkgs/r/noarch (che..  ⣾  pkgs/r/noarch (check zst)
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# pkgs/main/linux-64     2%
# pkgs/main/noarch      ⣾
# pkgs/r/linux-64       ⣾  pkgs/main/noarch
# [+] 0.2s
# conda-forge/linux-64   2%
# conda-forge/noarch     5%
# pkgs/main/linux-64    14%
# pkgs/r/linux-64       34%
# pkgs/r/noarch         ⣾  pkgs/r/linux-64
# [+] 0.3s
# conda-forge/linux-64   5%
# conda-forge/noarch    13%
# pkgs/main/linux-64    32%
# pkgs/r/noarch         36%[+] 0.4s
# conda-forge/linux-64   7%
# conda-forge/noarch    17%
# pkgs/main/linux-64    52%
# pkgs/r/noarch         97%pkgs/r/noarch
# [+] 0.5s
# conda-forge/linux-64   9%
# conda-forge/noarch    21%
# pkgs/main/linux-64    57%[+] 0.6s
# conda-forge/linux-64  12%
# conda-forge/noarch    28%
# pkgs/main/linux-64    75%[+] 0.7s
# conda-forge/linux-64  16%
# conda-forge/noarch    36%
# pkgs/main/linux-64    98%pkgs/main/linux-64
# [+] 0.8s
# conda-forge/linux-64  19%
# conda-forge/noarch    46%[+] 0.9s
# conda-forge/linux-64  24%
# conda-forge/noarch    52%[+] 1.0s
# conda-forge/linux-64  30%
# conda-forge/noarch    65%[+] 1.1s
# conda-forge/linux-64  36%
# conda-forge/noarch    78%[+] 1.2s
# conda-forge/linux-64  42%
# conda-forge/noarch    92%conda-forge/noarch
# [+] 1.3s
# conda-forge/linux-64  49%[+] 1.4s
# conda-forge/linux-64  56%[+] 1.5s
# conda-forge/linux-64  67%[+] 1.6s
# conda-forge/linux-64  77%[+] 1.7s
# conda-forge/linux-64  87%[+] 1.8s
# conda-forge/linux-64 100%conda-forge/linux-64
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - mdanalysis[version='>=1.0.0']
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package            Version  Build                    Channel          Size
# ──────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────
#
#   + fasteners           0.19  pyhd8ed1ab_1             conda-forge      21kB
#   + mmtf-python        1.1.3  pyhd8ed1ab_0             conda-forge      26kB
#   + tidynamics         1.1.2  pyhd8ed1ab_0             conda-forge      12kB
#   + mda-xdrlib         0.2.0  pyhd8ed1ab_1             conda-forge      17kB
#   + mrcfile            1.5.4  pyhd8ed1ab_0             conda-forge      39kB
#   + pyedr              0.8.0  pyhd8ed1ab_1             conda-forge     345kB
#   + griddataformats    1.0.2  pyhd8ed1ab_1             conda-forge       2MB
#   + pytng              0.3.3  py311h0eb78d4_1          conda-forge     531kB
#   + biopython           1.85  py311h9ecbd09_1          conda-forge       4MB
#   + gsd                3.4.2  py311h9ecbd09_0          conda-forge     269kB
#   + libaec             1.1.3  h59595ed_0               conda-forge      35kB
#   + cftime             1.6.4  py311h9f3472d_1          conda-forge     250kB
#   + hdf4              4.2.15  h2a13503_7               conda-forge     757kB
#   + libzip            1.11.2  h6991a6a_0               conda-forge     109kB
#   + snappy             1.2.1  h8bd8927_1               conda-forge      43kB
#   + hdf5              1.14.3  nompi_h2d575fe_109       conda-forge       4MB
#   + blosc             1.21.6  hef167b5_0               conda-forge      49kB
#   + h5py              3.13.0  nompi_py311hb639ac4_100  conda-forge       1MB
#   + libnetcdf          4.9.2  nompi_h135f659_114       conda-forge     849kB
#   + netcdf4            1.7.2  nompi_py311hae66bec_101  conda-forge       1MB
#   + mdanalysis         2.8.0  py311h7db5c69_0          conda-forge       5MB
#   + mdahole2-base      0.5.0  pyhd8ed1ab_1             conda-forge       4MB
#   + pathsimanalysis    1.2.0  pyhd8ed1ab_1             conda-forge      43kB
#   + waterdynamics      1.2.0  pyhd8ed1ab_1             conda-forge      31kB
#
#   Summary:
#
#   Install: 24 packages
#
#   Total download: 25MB
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%fasteners                                           20.7kB @ 183.8kB/s  0.1s
# mmtf-python                                         26.0kB @ 201.6kB/s  0.1s
# mda-xdrlib                                          16.5kB @ 128.1kB/s  0.1s
# tidynamics                                          12.0kB @  81.4kB/s  0.1s
# mrcfile                                             38.9kB @ 263.2kB/s  0.1s
# [+] 0.2s
# Downloading  (5)   2%
# Extracting   (3)  ⣾  snappy                                              42.7kB @ 188.5kB/s  0.1s
# pyedr                                              344.9kB @   1.5MB/s  0.1s
# gsd                                                269.5kB @   1.0MB/s  0.1s
# [+] 0.3s
# Downloading  (5)  13%
# Extracting   (5)  ⣾  libaec                                              35.4kB @ 109.6kB/s  0.1s
# hdf5                                                 3.9MB @  11.8MB/s  0.2s
# biopython                                            3.5MB @  10.2MB/s  0.2s
# mdahole2-base                                        3.7MB @  10.7MB/s  0.1s
# [+] 0.4s
# Downloading  (5)  53%
# Extracting   (7)  ⣾  libzip                                             109.0kB @ 271.7kB/s  0.1s
# cftime                                             249.9kB @ 617.5kB/s  0.1s
# libnetcdf                                          849.2kB @   2.1MB/s  0.1s
# waterdynamics                                       30.8kB @  74.2kB/s  0.1s
# netcdf4                                              1.2MB @   2.5MB/s  0.0s
# blosc                                               48.8kB @ 105.3kB/s  0.1s
# h5py                                                 1.4MB @   2.9MB/s  0.1s
# pytng                                              530.9kB @   1.1MB/s  0.1s
# [+] 0.5s
# Downloading  (4)  78%
# Extracting  (14)  ⣾  griddataformats                                      2.1MB @   4.1MB/s  0.1s
# pathsimanalysis                                     43.4kB @  78.7kB/s  0.1s
# hdf4                                               756.7kB @   1.3MB/s  0.1s
# mdanalysis                                           5.4MB @   9.1MB/s  0.4s
# [+] 0.6s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 0.7s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 0.8s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 0.9s
# Downloading      100%
# Extracting  (10)  ⣾  [+] 1.0s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 1.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 1.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 1.3s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 1.4s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 1.5s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 1.6s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 1.7s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['mdtraj']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾  pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
# [+] 0.1s
# pkgs/main/linux-64  ⣾
# pkgs/r/noarch       ⣾  pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - mdtraj
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package       Version  Build              Channel          Size
# ───────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────
#
#   + zlib-ng       2.2.4  h7955e40_0         conda-forge     109kB
#   + c-blosc2     2.15.2  h68e2383_0         conda-forge     342kB
#   + py-cpuinfo    9.0.0  pyhd8ed1ab_1       conda-forge      26kB
#   + nomkl           1.0  h5ca1d4c_0         conda-forge       4kB
#   + numexpr      2.10.2  py311h38b10cd_100  conda-forge     201kB
#   + pytables     3.10.2  py311h6d53d72_0    conda-forge       2MB
#   + mdtraj       1.10.3  py311h2ed89a0_0    conda-forge       2MB
#
#   Summary:
#
#   Install: 7 packages
#
#   Total download: 4MB
#
# ───────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%nomkl                                                3.8kB @  44.0kB/s  0.1s
# [+] 0.1s
# Downloading  (5)   1%
# Extracting   (1)  ⣾  py-cpuinfo                                          25.8kB @ 227.3kB/s  0.1s
# zlib-ng                                            108.8kB @ 713.7kB/s  0.2s
# c-blosc2                                           342.5kB @   2.0MB/s  0.2s
# numexpr                                            200.6kB @   1.2MB/s  0.2s
# [+] 0.2s
# Downloading  (2)  22%
# Extracting   (3)  ⣾  [+] 0.3s
# Downloading  (2)  36%
# Extracting   (1)  ⣾  mdtraj                                               1.6MB @   4.9MB/s  0.2s
# pytables                                             1.7MB @   4.5MB/s  0.3s
# [+] 0.4s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 0.5s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['plip']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# pkgs/main/linux-64                                          Using cache
# pkgs/main/noarch                                            Using cache
# pkgs/r/linux-64                                             Using cache
# pkgs/r/noarch                                               Using cache
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - plip
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package    Version  Build            Channel          Size
# ──────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────
#
#   + libxslt   1.1.39  h76b75d6_0       conda-forge     254kB
#   + lxml       5.3.0  py311hcfaa980_2  conda-forge       1MB
#   + plip       2.3.1  pyh29332c3_1     conda-forge      77kB
#
#   Summary:
#
#   Install: 3 packages
#
#   Total download: 2MB
#
# ──────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (1)   0%
# Extracting         0%[+] 0.1s
# Downloading  (3)   0%
# Extracting         0%plip                                                76.5kB @ 560.3kB/s  0.1s
# libxslt                                            254.3kB @   1.7MB/s  0.2s
# [+] 0.2s
# Downloading  (1)  21%
# Extracting   (2)  ⣾  lxml                                                 1.4MB @   5.4MB/s  0.3s
# [+] 0.3s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['openmm']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/r/linux-64                                               No change
# pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
# pkgs/main/noarch                                              No change
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - openmm
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                       Version  Build            Channel          Size
# ─────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────
#
#   + cudatoolkit                  11.8.0  h4ba93d1_13      conda-forge     716MB
#   + opencl-headers           2024.10.24  h5888daf_0       conda-forge      54kB
#   + ocl-icd                       2.3.2  hb9d3cd8_2       conda-forge      95kB
#   + ocl-icd-system                1.0.0  1                conda-forge       4kB
#   + kernel-headers_linux-64      3.10.0  he073ed8_18      conda-forge     943kB
#   + sysroot_linux-64               2.17  h0157908_18      conda-forge      15MB
#   + openmm                        8.2.0  py311he5bdeac_2  conda-forge      12MB
#
#   Summary:
#
#   Install: 7 packages
#
#   Total download: 744MB
#
# ─────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%ocl-icd                                             94.9kB @ 792.0kB/s  0.1s
# ocl-icd-system                                       4.3kB @  29.9kB/s  0.1s
# opencl-headers                                      54.1kB @ 376.9kB/s  0.1s
# [+] 0.2s
# Downloading  (4)   1%
# Extracting   (3)  ⣾  kernel-headers_linux-64                            943.5kB @   3.9MB/s  0.2s
# [+] 0.3s
# Downloading  (3)   1%
# Extracting   (2)  ⣾  [+] 0.4s
# Downloading  (3)   3%
# Extracting   (1)  ⣾  sysroot_linux-64                                    15.2MB @  32.1MB/s  0.4s
# [+] 0.5s
# Downloading  (2)   5%
# Extracting   (2)  ⣾  [+] 0.6s
# Downloading  (2)   6%
# Extracting   (2)  ⣾  [+] 0.7s
# Downloading  (2)   7%
# Extracting   (1)  ⣾  openmm                                              11.9MB @  17.0MB/s  0.6s
# [+] 0.8s
# Downloading  (1)   8%
# Extracting   (2)  ⣾  [+] 0.9s
# Downloading  (1)   9%
# Extracting   (2)  ⣾  [+] 1.0s
# Downloading  (1)   9%
# Extracting   (2)  ⣾  [+] 1.1s
# Downloading  (1)  10%
# Extracting   (2)  ⣾  [+] 1.2s
# Downloading  (1)  11%
# Extracting   (2)  ⣾  [+] 1.3s
# Downloading  (1)  12%
# Extracting   (2)  ⣾  [+] 1.4s
# Downloading  (1)  13%
# Extracting   (2)  ⣾  [+] 1.5s
# Downloading  (1)  14%
# Extracting   (2)  ⣾  [+] 1.6s
# Downloading  (1)  14%
# Extracting   (2)  ⣾  [+] 1.7s
# Downloading  (1)  15%
# Extracting   (2)  ⣾  [+] 1.8s
# Downloading  (1)  16%
# Extracting   (2)  ⣾  [+] 1.9s
# Downloading  (1)  16%
# Extracting   (2)  ⣾  [+] 2.0s
# Downloading  (1)  17%
# Extracting   (2)  ⣾  [+] 2.1s
# Downloading  (1)  18%
# Extracting   (2)  ⣾  [+] 2.2s
# Downloading  (1)  19%
# Extracting   (2)  ⣾  [+] 2.3s
# Downloading  (1)  20%
# Extracting   (2)  ⣾  [+] 2.4s
# Downloading  (1)  20%
# Extracting   (2)  ⣾  [+] 2.5s
# Downloading  (1)  21%
# Extracting   (1)  ⣾  [+] 2.6s
# Downloading  (1)  22%
# Extracting   (1)  ⣾  [+] 2.7s
# Downloading  (1)  23%
# Extracting   (1)  ⣾  [+] 2.8s
# Downloading  (1)  24%
# Extracting        86%[+] 2.9s
# Downloading  (1)  25%
# Extracting        86%[+] 3.0s
# Downloading  (1)  26%
# Extracting        86%[+] 3.1s
# Downloading  (1)  27%
# Extracting        86%[+] 3.2s
# Downloading  (1)  29%
# Extracting        86%[+] 3.3s
# Downloading  (1)  30%
# Extracting        86%[+] 3.4s
# Downloading  (1)  31%
# Extracting        86%[+] 3.5s
# Downloading  (1)  31%
# Extracting        86%[+] 3.6s
# Downloading  (1)  31%
# Extracting        86%[+] 3.7s
# Downloading  (1)  31%
# Extracting        86%[+] 3.8s
# Downloading  (1)  31%
# Extracting        86%[+] 3.9s
# Downloading  (1)  31%
# Extracting        86%[+] 4.0s
# Downloading  (1)  31%
# Extracting        86%[+] 4.1s
# Downloading  (1)  31%
# Extracting        86%[+] 4.2s
# Downloading  (1)  31%
# Extracting        86%[+] 4.3s
# Downloading  (1)  31%
# Extracting        86%[+] 4.4s
# Downloading  (1)  31%
# Extracting        86%[+] 4.5s
# Downloading  (1)  31%
# Extracting        86%[+] 4.6s
# Downloading  (1)  31%
# Extracting        86%[+] 4.7s
# Downloading  (1)  31%
# Extracting        86%[+] 4.8s
# Downloading  (1)  31%
# Extracting        86%[+] 4.9s
# Downloading  (1)  31%
# Extracting        86%[+] 5.0s
# Downloading  (1)  31%
# Extracting        86%[+] 5.1s
# Downloading  (1)  31%
# Extracting        86%[+] 5.2s
# Downloading  (1)  32%
# Extracting        86%[+] 5.3s
# Downloading  (1)  32%
# Extracting        86%[+] 5.4s
# Downloading  (1)  33%
# Extracting        86%[+] 5.5s
# Downloading  (1)  34%
# Extracting        86%[+] 5.6s
# Downloading  (1)  35%
# Extracting        86%[+] 5.7s
# Downloading  (1)  37%
# Extracting        86%[+] 5.8s
# Downloading  (1)  37%
# Extracting        86%[+] 5.9s
# Downloading  (1)  38%
# Extracting        86%[+] 6.0s
# Downloading  (1)  38%
# Extracting        86%[+] 6.1s
# Downloading  (1)  39%
# Extracting        86%[+] 6.2s
# Downloading  (1)  39%
# Extracting        86%[+] 6.3s
# Downloading  (1)  39%
# Extracting        86%[+] 6.4s
# Downloading  (1)  40%
# Extracting        86%[+] 6.5s
# Downloading  (1)  41%
# Extracting        86%[+] 6.6s
# Downloading  (1)  42%
# Extracting        86%[+] 6.7s
# Downloading  (1)  44%
# Extracting        86%[+] 6.8s
# Downloading  (1)  45%
# Extracting        86%[+] 6.9s
# Downloading  (1)  45%
# Extracting        86%[+] 7.0s
# Downloading  (1)  46%
# Extracting        86%[+] 7.1s
# Downloading  (1)  47%
# Extracting        86%[+] 7.2s
# Downloading  (1)  48%
# Extracting        86%[+] 7.3s
# Downloading  (1)  49%
# Extracting        86%[+] 7.4s
# Downloading  (1)  51%
# Extracting        86%[+] 7.5s
# Downloading  (1)  51%
# Extracting        86%[+] 7.6s
# Downloading  (1)  52%
# Extracting        86%[+] 7.7s
# Downloading  (1)  53%
# Extracting        86%[+] 7.8s
# Downloading  (1)  54%
# Extracting        86%[+] 7.9s
# Downloading  (1)  55%
# Extracting        86%[+] 8.0s
# Downloading  (1)  56%
# Extracting        86%[+] 8.1s
# Downloading  (1)  57%
# Extracting        86%[+] 8.2s
# Downloading  (1)  58%
# Extracting        86%[+] 8.3s
# Downloading  (1)  59%
# Extracting        86%[+] 8.4s
# Downloading  (1)  59%
# Extracting        86%[+] 8.5s
# Downloading  (1)  60%
# Extracting        86%[+] 8.6s
# Downloading  (1)  61%
# Extracting        86%[+] 8.7s
# Downloading  (1)  62%
# Extracting        86%[+] 8.8s
# Downloading  (1)  63%
# Extracting        86%[+] 8.9s
# Downloading  (1)  64%
# Extracting        86%[+] 9.0s
# Downloading  (1)  64%
# Extracting        86%[+] 9.1s
# Downloading  (1)  64%
# Extracting        86%[+] 9.2s
# Downloading  (1)  65%
# Extracting        86%[+] 9.3s
# Downloading  (1)  66%
# Extracting        86%[+] 9.4s
# Downloading  (1)  66%
# Extracting        86%[+] 9.5s
# Downloading  (1)  66%
# Extracting        86%[+] 9.6s
# Downloading  (1)  67%
# Extracting        86%[+] 9.7s
# Downloading  (1)  68%
# Extracting        86%[+] 9.8s
# Downloading  (1)  69%
# Extracting        86%[+] 9.9s
# Downloading  (1)  70%
# Extracting        86%[+] 10.0s
# Downloading  (1)  71%
# Extracting        86%[+] 10.1s
# Downloading  (1)  72%
# Extracting        86%[+] 10.2s
# Downloading  (1)  73%
# Extracting        86%[+] 10.3s
# Downloading  (1)  75%
# Extracting        86%[+] 10.4s
# Downloading  (1)  75%
# Extracting        86%[+] 10.5s
# Downloading  (1)  76%
# Extracting        86%[+] 10.6s
# Downloading  (1)  76%
# Extracting        86%[+] 10.7s
# Downloading  (1)  77%
# Extracting        86%[+] 10.8s
# Downloading  (1)  79%
# Extracting        86%[+] 10.9s
# Downloading  (1)  80%
# Extracting        86%[+] 11.0s
# Downloading  (1)  81%
# Extracting        86%[+] 11.1s
# Downloading  (1)  82%
# Extracting        86%[+] 11.2s
# Downloading  (1)  83%
# Extracting        86%[+] 11.3s
# Downloading  (1)  84%
# Extracting        86%[+] 11.4s
# Downloading  (1)  84%
# Extracting        86%[+] 11.5s
# Downloading  (1)  85%
# Extracting        86%[+] 11.6s
# Downloading  (1)  87%
# Extracting        86%[+] 11.7s
# Downloading  (1)  88%
# Extracting        86%[+] 11.8s
# Downloading  (1)  89%
# Extracting        86%[+] 11.9s
# Downloading  (1)  90%
# Extracting        86%[+] 12.0s
# Downloading  (1)  91%
# Extracting        86%[+] 12.1s
# Downloading  (1)  92%
# Extracting        86%[+] 12.2s
# Downloading  (1)  93%
# Extracting        86%[+] 12.3s
# Downloading  (1)  94%
# Extracting        86%[+] 12.4s
# Downloading  (1)  95%
# Extracting        86%[+] 12.5s
# Downloading  (1)  96%
# Extracting        86%[+] 12.6s
# Downloading  (1)  97%
# Extracting        86%[+] 12.7s
# Downloading  (1)  97%
# Extracting        86%[+] 12.8s
# Downloading  (1)  99%
# Extracting        86%[+] 12.9s
# Downloading  (1) 100%
# Extracting        86%cudatoolkit                                        715.6MB @  55.1MB/s 13.0s
# [+] 13.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 21.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 22.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 23.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 24.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 25.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 26.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 27.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 28.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 29.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 30.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 31.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 32.9s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.0s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.1s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.2s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.3s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 33.9s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# - By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
#
# Looking for: ["mkl[version='<2022']"]
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# [+] 0.1s
# pkgs/main/linux-64  ⣾
# pkgs/main/noarch    ⣾
# pkgs/r/linux-64     ⣾
# pkgs/r/noarch                                      100%pkgs/r/noarch
# pkgs/r/linux-64
# pkgs/main/linux-64
# pkgs/main/noarch
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - mkl[version='<2022']
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package            Version  Build                  Channel           Size
# ─────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────
#
#   + liblapacke         3.9.0  31_he2f377e_openblas   conda-forge       17kB
#   + openblas          0.3.29  pthreads_h6ec200e_0    conda-forge        6MB
#   + llvm-openmp       19.1.7  h024ca30_0             conda-forge        3MB
#   + libhwloc          2.11.2  default_he43201b_1000  conda-forge        2MB
# ...
# ──────────────────────────────────────────────────────────────────
#
#   + sphinx-gallery   0.19.0  pyhd8ed1ab_0  conda-forge     390kB
#
#   Summary:
#
#   Install: 1 packages
#
#   Total download: 390kB
#
# ──────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading  (1)   0%
# Extracting         0%[+] 0.1s
# Downloading  (1)   0%
# Extracting         0%sphinx-gallery                                     389.5kB @   2.3MB/s  0.2s
# [+] 0.2s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
#
# Looking for: ['autodocsumm']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
# pkgs/main/linux-64  ⣾  pkgs/main/linux-64                                            No change
# pkgs/r/noarch                                                 No change
# [+] 0.1s
# pkgs/main/noarch  ⣾
# pkgs/r/linux-64   ⣾  pkgs/r/linux-64                                               No change
# pkgs/main/noarch                                              No change
#
# Pinned packages:
#   - python 3.11.*
#   - python 3.11.*
#   - python_abi 3.11.* *cp311*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - autodocsumm
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package        Version  Build         Channel         Size
# ──────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────
#
#   + autodocsumm   0.2.14  pyhd8ed1ab_0  conda-forge     19kB
#
#   Summary:
#
#   Install: 1 packages
#
#   Total download: 19kB
#
# ──────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%autodocsumm                                         19.2kB @ 205.2kB/s  0.1s
# [+] 0.1s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages:
#
# done
# done
# done
# Collecting black-nb
#   Downloading black-nb-0.7.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting nbsphinx-link
#   Downloading nbsphinx_link-1.3.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting sphinxext-opengraph
#   Downloading sphinxext_opengraph-0.9.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting deepchem
#   Downloading deepchem-2.8.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/site-packages (from black-nb) (25.1.0)
# Collecting black>=21.9b0 (from black[jupyter]>=21.9b0->black-nb)
#   Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (81 kB)
# Collecting click>=7.0 (from black-nb)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: nbformat>=4.4.0 in /usr/local/lib/python3.11/site-packages (from black-nb) (5.10.4)
# Requirement already satisfied: nbsphinx in /usr/local/lib/python3.11/site-packages (from nbsphinx-link) (0.9.6)
# Requirement already satisfied: sphinx>=1.8 in /usr/local/lib/python3.11/site-packages (from nbsphinx-link) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/site-packages (from deepchem) (1.4.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.11/site-packages (from deepchem) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (from deepchem) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/site-packages (from deepchem) (1.6.1)
# Collecting sympy (from deepchem)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.11/site-packages (from deepchem) (1.15.2)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.11/site-packages (from deepchem) (2023.9.6)
# Collecting mypy-extensions>=0.4.3 (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.11/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (24.2)
# Collecting pathspec>=0.9.0 (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/site-packages (from black>=21.9b0->black[jupyter]>=21.9b0->black-nb) (4.3.6)
# Requirement already satisfied: ipython>=7.8.0 in /usr/local/lib/python3.11/site-packages (from black[jupyter]>=21.9b0->black-nb) (8.32.0)
# Collecting tokenize-rt>=3.2.0 (from black[jupyter]>=21.9b0->black-nb)
#   Downloading tokenize_rt-6.1.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/site-packages (from nbformat>=4.4.0->black-nb) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/site-packages (from nbformat>=4.4.0->black-nb) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/site-packages (from nbformat>=4.4.0->black-nb) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /usr/local/lib/python3.11/site-packages (from nbformat>=4.4.0->black-nb) (5.14.3)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (1.1.10)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (3.1.5)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (2.19.1)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (2.32.3)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/site-packages (from sphinx>=1.8->nbsphinx-link) (3.1.0)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in /usr/local/lib/python3.11/site-packages (from nbsphinx->nbsphinx-link) (7.16.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas->deepchem) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas->deepchem) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas->deepchem) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/site-packages (from scikit-learn->deepchem) (3.5.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->deepchem)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.11/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (3.0.50)
# Requirement already satisfied: stack_data in /usr/local/lib/python3.11/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /usr/local/lib/python3.11/site-packages (from ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (4.12.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from Jinja2>=3.1->sphinx>=1.8->nbsphinx-link) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->black-nb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->black-nb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat>=4.4.0->black-nb) (0.23.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/site-packages (from nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests>=2.30.0->sphinx>=1.8->nbsphinx-link) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests>=2.30.0->sphinx>=1.8->nbsphinx-link) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests>=2.30.0->sphinx>=1.8->nbsphinx-link) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests>=2.30.0->sphinx>=1.8->nbsphinx-link) (2025.1.31)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.8.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/site-packages (from nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (7.4.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/site-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (2.5)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.11/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.11/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (3.0.0)
# Requirement already satisfied: pure_eval in /usr/local/lib/python3.11/site-packages (from stack_data->ipython>=7.8.0->black[jupyter]>=21.9b0->black-nb) (0.2.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (1.6.0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.11/site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert!=5.4,>=5.3->nbsphinx->nbsphinx-link) (6.4.2)
# Downloading nbsphinx_link-1.3.1-py3-none-any.whl (5.2 kB)
# Downloading sphinxext_opengraph-0.9.1-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.6 MB/s eta 0:00:00
# Downloading deepchem-2.8.0-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 37.4 MB/s eta 0:00:00
# Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 60.8 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 75.5 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 19.1 MB/s eta 0:00:00
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading tokenize_rt-6.1.0-py2.py3-none-any.whl (6.0 kB)
# Building wheels for collected packages: black-nb
#   Building wheel for black-nb (pyproject.toml) ... done
#   Created wheel for black-nb: filename=black_nb-0.7-py3-none-any.whl size=10124 sha256=97624c4637e0bad5199cc4c0c60f7565225aee163b8be6ae2d97aa6bbf0ff064
#   Stored in directory: /root/.cache/pip/wheels/c4/aa/cb/f9c80cd83c07a7cc06f97e4bd270f1580006066ec4168792ae
# Successfully built black-nb
# Installing collected packages: mpmath, tokenize-rt, sympy, pathspec, mypy-extensions, click, black, sphinxext-opengraph, deepchem, black-nb, nbsphinx-link
# Successfully installed black-25.1.0 black-nb-0.7 click-8.1.8 deepchem-2.8.0 mpmath-1.3.0 mypy-extensions-1.0.0 nbsphinx-link-1.3.1 pathspec-0.12.1 sphinxext-opengraph-0.9.1 sympy-1.13.3 tokenize-rt-6.1.0

# %% [markdown]
# ## Practical

# %%
from collections import defaultdict
from pathlib import Path
from copy import deepcopy
import random

from ipywidgets import interact, fixed, widgets
import pandas as pd
import matplotlib.pyplot as plt
from rdkit import Chem, Geometry
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdFMCS

# %%
import time
import random
from pathlib import Path

import pandas as pd
import numpy
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit import DataStructs
from rdkit.ML.Cluster import Butina
from rdkit.Chem import Draw
from rdkit.Chem import rdFingerprintGenerator

# %% [markdown]
# ### Load and draw molecules
#
# Cluster data taken from **Part 5** or later EGFR molecules from **Part 1**

# %%
sdf = str("/content/sample_data/molecule_set_largest_cluster-2.sdf")
supplier = Chem.ForwardSDMolSupplier(sdf)
mols = list(supplier)

print(f"Set with {len(mols)} molecules loaded.")
# NBVAL_CHECK_OUTPUT
# Out:
# Set with 222 molecules loaded.

# %%
# Show only first 10 molecules -- use slicing
num_mols = 10
legends = [mol.GetProp("_Name") for mol in mols]
Draw.MolsToGridImage(mols[:num_mols], legends=legends[:num_mols], molsPerRow=5)

# %% [markdown]
# ### Run the FMCS algorithm with different input parameters
#
# The FMCS algorithm is implemented in RDKit: [rdFMCS](https://rdkit.org/docs/source/rdkit.Chem.rdFMCS.html)

# %% [markdown]
# #### Default values
#
# In the simplest case only a list of molecules is given as a parameter.

# %%
mcs1 = rdFMCS.FindMCS(mols)
print(f"MCS1 contains {mcs1.numAtoms} atoms and {mcs1.numBonds} bonds.")
print("MCS SMARTS string:", mcs1.smartsString)
# NBVAL_CHECK_OUTPUT
# Out:
# MCS1 contains 13 atoms and 13 bonds.
# MCS SMARTS string: [#6]:[#6](:[#7]:[#6]):[#6]:[#6]-[#7]-[#6]1:[#6]:[#6]:[#6]:[#6]:[#6]:1

# %%
# Draw substructure from Smarts
m1 = Chem.MolFromSmarts(mcs1.smartsString)
Draw.MolToImage(m1, legend="MCS1")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %% [markdown]
# Define a helper function to draw the molecules with the highlighted MCS.

# %%
def highlight_molecules(molecules, mcs, number, label=True, same_orientation=True, **kwargs):
    """Highlight the MCS in our query molecules"""
    molecules = deepcopy(molecules)
    # convert MCS to molecule
    pattern = Chem.MolFromSmarts(mcs.smartsString)
    # find the matching atoms in each molecule
    matching = [molecule.GetSubstructMatch(pattern) for molecule in molecules[:number]]

    legends = None
    if label is True:
        legends = [x.GetProp("_Name") for x in molecules]

    # Align by matched substructure so they are depicted in the same orientation
    # Adapted from: https://gist.github.com/greglandrum/82d9a86acb3b00d3bb1df502779a5810
    if same_orientation:
        mol, match = molecules[0], matching[0]
        AllChem.Compute2DCoords(mol)
        coords = [mol.GetConformer().GetAtomPosition(x) for x in match]
        coords2D = [Geometry.Point2D(pt.x, pt.y) for pt in coords]
        for mol, match in zip(molecules[1:number], matching[1:number]):
            if not match:
                continue
            coord_dict = {match[i]: coord for i, coord in enumerate(coords2D)}
            AllChem.Compute2DCoords(mol, coordMap=coord_dict)

    return Draw.MolsToGridImage(
        molecules[:number],
        legends=legends,
        molsPerRow=5,
        highlightAtomLists=matching[:number],
        subImgSize=(200, 200),
        **kwargs,
    )

# %%
highlight_molecules(mols, mcs1, 5)

# %% [markdown]
# Save image to disk

# %%
img = highlight_molecules(mols, mcs1, 3, useSVG=True)

# Get SVG data
molsvg = img.data

# Set background to transparent & Enlarge size of label
molsvg = molsvg.replace("opacity:1.0", "opacity:0.0").replace("12px", "20px")

# Save altered SVG data to file
with open("mcs_largest_cluster.svg", "w") as f:
    f.write(molsvg)

# %% [markdown]
# #### Set a threshold
#
# It is possible to lower the threshold for the substructure, for example so that the MCS only has to occur in e.g. 80% of the input structures.

# %%
mcs2 = rdFMCS.FindMCS(mols, threshold=0.8)
print(f"MCS2 contains {mcs2.numAtoms} atoms and {mcs2.numBonds} bonds.")
print("SMARTS string:", mcs2.smartsString)
# NBVAL_CHECK_OUTPUT
# Out:
# MCS2 contains 18 atoms and 19 bonds.
# SMARTS string: [#6]-[#8]-[#6]1:[#6]:[#6](:[#7]:[#6]):[#6](:[#6]:[#6]:1):[#6]-[#7]-[#6]1:[#6]:[#6]:[#6]:[#6]:[#6]:1

# %%
# Draw substructure
m2 = Chem.MolFromSmarts(mcs2.smartsString)
Draw.MolsToGridImage([m1, m2], legends=["MCS1", "MCS2: +threshold=0.8"])

# %%
highlight_molecules(mols, mcs2, 5)

# %% [markdown]
# <!-- FIXME: CI - CHEMBL27685 id is not in this subset, check that T005 produces deterministic outputs -->
# As we can see in this example, some molecules were now left out due to the set threshold (`0.8`). This threshold allows to find a larger common substructure that contains, e.g., a benzene with a meta-substitution fluor pattern and a longer alkane chain.

# %% [markdown]
# #### Match ring bonds
#
# In the above example it may not be obvious, but by default ring bonds can match non-ring bonds.
# Often from an application point of view, we want to retain rings. Thus, one can set the `ringMatchesRingOnly` parameter to ```True```, then only ring bonds match with other ring bonds.

# %%
mcs3 = rdFMCS.FindMCS(mols, threshold=0.8, ringMatchesRingOnly=True)
print(f"MCS3 contains {mcs3.numAtoms} atoms and {mcs3.numBonds} bonds.")
print("SMARTS string:", mcs3.smartsString)
# NBVAL_CHECK_OUTPUT
# Out:
# MCS3 contains 17 atoms and 19 bonds.
# SMARTS string: [#6]1:&@[#6]:&@[#6]2:&@[#7]:&@[#6]:&@[#7]:&@[#6](:&@[#6]:&@2:&@[#6]:&@[#6]:&@1)-&!@[#7&!R]-&!@[#6]1:&@[#6]:&@[#6]:&@[#6]:&@[#6]:&@[#6]:&@1

# %%
# Draw substructure
m3 = Chem.MolFromSmarts(mcs3.smartsString)
Draw.MolsToGridImage([m1, m2, m3], legends=["MCS1", "MCS2: +treshold=0.8", "mcs3: +ringmatch"])

# %% [markdown]
# We can see here that depending on the chosen thresholds and parameters, we get slightly different MCS. Note that there are more parameter options available in the [RDKit FMCS module](https://www.rdkit.org/docs/GettingStartedInPython.html#maximum-common-substructure), e.g. considering atom, bond or valence matching.

# %%
highlight_molecules(mols, mcs3, 5)

# %% [markdown]
# ### A more diverse set: the EGFR compounds downloaded from ChEMBL
#
# We restrict the data to only highly active molecules (pIC50>9) and detect the maximum common scaffold in this subset.

# %%
# Read full EGFR data
mol_df = pd.read_csv("/content/sample_data/MDB231_ro5_properties_filtered.csv", index_col=0)
print("Total number of compounds:", mol_df.shape[0])

# Only keep molecules with pIC50 > 9 (IC50 > 1nM)
mol_df = mol_df[mol_df.pIC50 > 9]
print("Number of compounds with pIC50 > 9:", mol_df.shape[0])
# NBVAL_CHECK_OUTPUT
# Out:
# Total number of compounds: 1350
# Number of compounds with pIC50 > 9: 6

# %%
from rdkit.Chem import PandasTools
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-851e0ccb422b> in <cell line: 0>()
# ----> 1 from rdkit.Chem import PandasTools
#
# /usr/local/lib/python3.11/site-packages/rdkit/Chem/PandasTools.py in <module>
#     651
#     652
# --> 653 InstallPandasTools()
#     654
#     655 if __name__ == '__main__':  # pragma: nocover
#
# /usr/local/lib/python3.11/site-packages/rdkit/Chem/PandasTools.py in InstallPandasTools()
#     620   """ Monkey patch an RDKit method of Chem.Mol and pandas """
#     621   try:
# --> 622     PandasPatcher.patchPandas()
#     623   except NameError:
#     624     pass
#
# /usr/local/lib/python3.11/site-packages/rdkit/Chem/PandasPatcher.py in patchPandas()
#     261   if getattr(html_formatter_class, "_write_cell") != patched_write_cell:
#     262     setattr(html_formatter_class, "_write_cell", patched_write_cell)
# --> 263   if getattr(pandas_formats.format, get_adjustment_name) != patched_get_adjustment:
#     264     setattr(pandas_formats.format, get_adjustment_name, patched_get_adjustment)
#     265   if (orig_get_formatter and getattr(dataframeformatter_class, "_get_formatter") != patched_get_formatter):
#
# AttributeError: module 'pandas.io.formats.format' has no attribute 'get_adjustment'

# %%
# Add molecule column to data frame
PandasTools.AddMoleculeColumnToFrame(mol_df, "smiles")
mol_df.head(3)

# %% [markdown]
# We do our calculations on the selected highly active molecules only.

# %%
mols_diverse = []
# Note: discarded variables we do not care about are usually referred to with a single underscore
for _, row in mol_df.iterrows():
    m = Chem.MolFromSmiles(row.smiles)
    m.SetProp("_Name", row.molecule_chembl_id)
    mols_diverse.append(m)

# %% [markdown]
# In the interest of time, we randomly pick 50 molecules from this set.

# %%
# We have fixed the random seed above (imports) for deterministic results
mols_diverse_sample = random.sample(mols_diverse, 6)

# %% [markdown]
# We now calculate the same three variants of MCSs as described above and draw the respective substructures. We use a slightly lower threshold to account for the larger diversity in the set.

# %%
threshold_diverse = 0.7
mcs1 = rdFMCS.FindMCS(mols_diverse_sample)
print("SMARTS string1:", mcs1.smartsString)
mcs2 = rdFMCS.FindMCS(mols_diverse_sample, threshold=threshold_diverse)
print("SMARTS string2:", mcs2.smartsString)
mcs3 = rdFMCS.FindMCS(mols_diverse_sample, ringMatchesRingOnly=True, threshold=threshold_diverse)
print("SMARTS string3:", mcs3.smartsString)
# NBVAL_CHECK_OUTPUT
# Out:
# SMARTS string1: [#6](:[#6]-[#7]-[#6](=[#8])-[#6]):[#6]-,:[#6]-,:[#6]
# SMARTS string2: [#6](:[#6]-[#7]-[#6]:,-[#6]:[#6]:[#6]:[#6]:,-[#6]):[#6](:,-[#7]:,-[#6]:[#7]):[#6]
# SMARTS string3: [#6&R](-&!@[#7&!R]-&!@[#6]1:&@[#6]:&@[#6]:&@[#6]:&@[#6]:&@[#6]:&@1):&@[#7&R]:&@[#6&R]

# %%
# Draw substructures
m1 = Chem.MolFromSmarts(mcs1.smartsString)
m2 = Chem.MolFromSmarts(mcs2.smartsString)
m3 = Chem.MolFromSmarts(mcs3.smartsString)

Draw.MolsToGridImage(
    [m1, m2, m3],
    legends=[
        "MCS1",
        f"MCS2: +threshold={threshold_diverse}",
        "MCS3: +ringmatch",
    ],
)

# %% [markdown]
# This time it become more clear that setting `ringMatchesRingOnly=True` provides a more intuitive representation of the scaffold they share.

# %%
highlight_molecules(mols_diverse_sample, mcs3, 10)

# %% [markdown]
# ### Identification of MCS using interactive cut-off adaption
#
# We can also change the threshold interactively. For that, we need a helper function, hereby defined. It takes two arguments: `molecules` (fixed, so it's not configurable with a widget) and `percentage` (the value of which is determined by the interactive widget). Every time you modify the state of the slider, this helper function is called.

# %%
def render_mcs(molecules, percentage):
    """Interactive widget helper. `molecules` must be wrapped in `ipywidgets.fixed()`,
    while `percentage` will be determined by an IntSlider widget."""
    tmcs = rdFMCS.FindMCS(molecules, threshold=percentage / 100.0)
    if tmcs is None:
        print("No MCS found")
        return None

    m = Chem.MolFromSmarts(tmcs.smartsString)
    print(tmcs.smartsString)
    return m

# %%
# Note that the slider may take a few seconds to react
interact(
    render_mcs,
    molecules=fixed(mols_diverse_sample),
    percentage=widgets.IntSlider(min=0, max=100, step=10, value=70),
);
# Out:
# interactive(children=(IntSlider(value=70, description='percentage', step=10), Output()), _dom_classes=('widget…

# %% [markdown]
# ## Discussion
#
# Maximum substructures that a set of molecules have in common can a useful strategy to visualize common scaffolds. In this talktorial, we have use the FMCS algorithm to find the maximum common substructure within a largest cluster from **Part 5**. An interactive widget allowed us to explore the impact of different thresholds on the maximum common substructure in our dataset.

# %% [markdown]
# ##**Congratulation! Awesome - You did not quit**
#
# If you happy for your time, Please provide your Support in the Form of a Subscription on Youtube Channel**
#
# [**Bioinformatics Insights**](https://www.youtube.com/channel/UC2Z_WaqTjbvXGGQNpIF9nAg)
#
# Follow [**WhatsApp Channel**](https://whatsapp.com/channel/0029VajkwkdCHDydS6Y2lM36) for further updates, research services, and courses.
